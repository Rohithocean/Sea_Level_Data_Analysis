# %%
# %load_ext ferretmagic

# %%
# %%ferret
# cancel data/al
# use coads_climatology

# %%
# %%ferret
# palette cmocean_balance
# set win/asp=.7
# fill/l=1 sst ; go land 7
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO land 7
# ! Exit_GO
# </pre>
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>
